# %%
import sympy as sp

# %% [markdown]
# # Assumptions so far
#
# - $ \bar{\alpha} \cdot \bar{\alpha} \approx 0 $
# - $ \bar{V_x} = 0 $
# - $ \tan{(\bar{\alpha_r})} \approx \alpha_r $
# - $ \dot{\alpha_{r0}}\prime = 0 $
# - $ \dot{\varphi_0} = 0 $
# - $ \dot{\varphi_f0} = 0 $
# - $ \dot{\Delta_0} = 0 $
# - $ \ddot{\alpha_0} = 0 $
# - $ \dot{\omega_{i0}} = 0 $
# - $ \bar{X_r} = 0 $

# %%
Delta_0, Delta, delta_0, delta = sp.symbols('Delta_0, Deltabar, delta_0, deltabar')
phi_0, phi, phi_f0, phi_f = sp.symbols('varphi_0, varphibar, varphi_f0, varphibar_f')
omega_r0, omega_r, omega_f0, omega_f = sp.symbols('omega_r0, omegabar_r, omega_f0, omegabar_f')
beta_0, beta = sp.symbols('beta_0, betabar')

psi_0_dot, psi_dot, psi_ddot = sp.symbols('psidot_0, psibardot, psibarddot')
eps = sp.symbols('epsilon')

phi_0_dot, phi_dot, phi_f0_dot, phi_f_dot = sp.symbols('varphidot_0, varphibardot, varphidot_f0, varphibardot_f')
delta_0_dot, delta_dot = sp.symbols('deltadot_0, deltabardot')
beta_0_dot, beta_dot = sp.symbols('betadot_0, betabardot')
omega_r_dot, omega_f_dot = sp.symbols('omegabardot_r, omegabardot_f')
Delta_dot, Delta_ddot, Delta_0_dot, Delta_0_ddot = sp.symbols('Deltabardot, Deltabarddot, Deltadot_0, Deltaddot_0')

phi_ddot, phi_f_ddot, delta_ddot, beta_ddot = sp.symbols('varphibarddot, varphibarddot_f, deltabarddot, betabarddot')

alpha_r0, alpha_r, alpha_f0, alpha_f = sp.symbols('alpha_r0, alphabar_r, alpha_f0, alphabar_f')

R, R_r, R_f = sp.symbols('R, R_r, R_f')
rho_r, rho_f = sp.symbols('rho_r, rho_f')
a_n, w, l_b = sp.symbols('a_n, w, l_b')
b, m, g, h = sp.symbols('b, m, g, h')
b_a, w_a, L, D, h_a = sp.symbols('b_a, w_a, L, D, h_a')
m_f, e_f, m_b, z_b, b_f, e_b = sp.symbols('m_f, e_f, m_b, z_b, b_f, e_b')
h_f, h_b, b_b = sp.symbols('h_f, h_b, b_b')
Vx0, Vx, Vy0, Vy = sp.symbols('V_x0, Vbar_x, V_y0, Vbar_y')
Vy0_dot, Vy_dot = sp.symbols('Vdot_y0, Vbardot_y0')
Xr0, Xf0, Xr, Xf = sp.symbols('X_r0, X_f0, Xbar_r, Xbar_f')
rho_f, rho_r = sp.symbols('rho_f, rho_r')
M_delta, c_delta = sp.symbols('M_delta, c_delta')

Ixz, Ixx, Ifzz, Ibxx, Iwf, Iwr= sp.symbols('I_xz, I_xx, I_fzz, I_bxx, I_omega_f, I_omega_r')
Ibzz, Izz = sp.symbols('I_bzz, I_zz')

N_r0, N_r, N_f0, N_f = sp.symbols('N_r0, Nbar_r, N_f0, Nbar_f')

Y_r0, Y_r, Y_f0, Y_f = sp.symbols('Y_r0, Ybar_r, Y_f0, Ybar_f')
M_rz0, M_rz, M_yz0, M_yz = sp.symbols('M_rz0, Mbar_rz, M_fz0, Mbar_fz')

k_alpha_r, k_gamma_r, k_alpha_f, k_gamma_f = sp.symbols('k_alpha_r, k_gamma_r, k_alpha_f, k_gamma_f')
k_a_r, k_t_r, k_a_f, k_t_f = sp.symbols('k_a_r, k_t_r, k_a_f, k_t_f')
alpha_r0_prima, alpha_r_prima, alpha_f0_prima, alpha_f_prima = sp.symbols('alphaprime_r0, alphabarprime_r, alphaprime_f0, alphabarprime_f')

# %%
delta_0 = (sp.cos(phi_0)*Delta_0 + sp.sin(eps)*beta_0)/sp.cos(eps)
delta = (sp.cos(phi_0)*Delta - sp.sin(phi_0)*phi*Delta_0 + sp.sin(eps)*beta)/sp.cos(eps)

Delta_0 = sp.atan(w/R)
psi_dot_0 = Vx0/R
Vy0_dot = Vx0**2/R

phi_f0 = sp.asin(sp.sin(phi_0) + sp.cos(phi_0)*sp.sin(eps)*delta_0 + sp.cos(eps)*sp.cos(phi_0)*beta_0)
phi_f = (sp.cos(phi_0)*phi + sp.sin(eps)*(sp.cos(phi_0)*delta - sp.sin(phi_0)*phi*delta_0) + 
         sp.cos(eps)*(sp.cos(phi_0)*beta - sp.sin(phi_0)*phi*beta_0))/sp.cos(phi_f0)

omega_r0 = Vx0/(R_r + rho_r*(sp.cos(phi_0)-1))
omega_r = (Vx0*rho_r*sp.sin(phi_0)*phi)/(R_r + rho_r*(sp.cos(phi_0)-1))**2

omega_f0 = Vx0/((R_f + rho_f*(sp.cos(phi_f0) - 1))*sp.cos(Delta_0))
omega_f = Vx0/(-R_f*sp.sin(Delta_0)*Delta - rho_f*(sp.cos(phi_f0)*sp.sin(Delta_0)*Delta + sp.sin(phi_f0)*phi_f*sp.cos(Delta_0) + sp.sin(Delta_0)*Delta))

alpha_r0 = sp.atan(Vy0/Vx0)
alpha_r = Vy/(Vx0 + Vy0*sp.tan(alpha_r0))

alpha_f0 = Delta_0 + (a_n*delta_0_dot - w*psi_0_dot - Vy0 + l_b*beta_0*sp.cos(delta_0) - rho_f*sp.cos(eps)*beta_0*sp.cos(delta_0))/Vx0
alpha_f = Delta + (a_n*delta_dot - w*psi_dot - Vy - l_b*(beta_0*sp.sin(delta_0)*delta - beta*sp.cos(delta_0)) + rho_f*(sp.cos(eps)*beta_0*sp.sin(delta_0*delta) - sp.cos(eps)*beta*sp.cos(delta_0)))/Vx0

Y_r0 = (k_alpha_r*alpha_r0_prima + k_gamma_r*phi_0)*N_r0
Y_r = (k_alpha_r*alpha_r0_prima + k_gamma_r*phi_0)*N_r + k_alpha_r*alpha_r_prima*N_r0 + k_gamma_r*phi*N_r0

Y_f0 = (k_alpha_f*alpha_f0_prima + k_gamma_f*phi_f0)*N_f0
Y_f = (k_alpha_f*alpha_f0_prima + k_gamma_f*phi_f0)*N_f + k_alpha_f*alpha_f_prima*N_f0 + k_gamma_f*phi_f*N_f0

Y_r0 = (k_alpha_r*alpha_r0_prima + k_gamma_r*phi_0)*N_r0
Y_r = (k_alpha_r*alpha_r0_prima + k_gamma_r*phi_0)*N_r + k_alpha_r*alpha_r_prima*N_r0 + k_gamma_r*phi*N_r0

Y_f0 = (k_alpha_f*alpha_f0_prima + k_gamma_f*phi_f0)*N_f0
Y_f = (k_alpha_f*alpha_f0_prima + k_gamma_f*phi_f0)*N_f + k_alpha_f*alpha_f_prima*N_f0 + k_gamma_f*phi_f*N_f0

M_rz0 = (k_a_r*alpha_r0_prima + k_t_r*phi_0)*N_r0
M_r = (k_a_r*alpha_r0_prima + k_t_r*phi_0)*N_r + k_a_r*alpha_r_prima*N_r0 + k_t_r*phi*N_r0

M_fz0 = (k_a_f*alpha_f0_prima + k_t_f*phi_f0)*N_f0
M_fz = (k_a_f*alpha_f0_prima + k_t_f*phi_f0)*N_f + k_a_f*alpha_f_prima*N_f0 + k_t_f*phi_f*N_f0

N_r0 = 0 # Completar
N_r = ((b_a/w_a) - 1)*L*sp.sin(phi_0)*phi

N_f0 = 0 # Completar
N_f = -(b_a/w_a)*L*sp.sin(phi_0)*phi

sum_y_v_left = m*(Vy_dot + b*psi_ddot + h*sp.cos(phi_0)*phi_ddot + Vx0*psi_dot) + m_f*e_f*delta_ddot - m_b*z_b*beta_ddot
sum_y_v_right = Y_r - Y_f0*sp.sin(Delta_0)*Delta + Y_f*sp.cos(Delta_0) - L*sp.cos(phi_0)*phi
sum_y = sp.Eq(sum_y_v_left, sum_y_v_right)

mx_v_left = (m*b*h - Ixz)*psi_ddot + (m*h**2 + Ixx)*psi_ddot + \
    (m_f*e_f*h_f + Ifzz*sp.sin(eps))*delta_ddot + \
    (Ibxx*sp.cos(eps) - m_b*h_b*z_b)*beta_ddot + \
    m*h*(Vy_dot + Vx0*psi_dot) + Iwf*(omega_f0*psi_dot + omega_f*psi_0_dot) + \
    Iwr*(omega_r0*psi_dot + omega_r*psi_0_dot) + \
    Iwf*(omega_f0*Delta_dot + omega_f_dot*Delta_0)

mx_v_right = (a_n - sp.sin(eps)*rho_f)*(sp.sin(delta_0)*N_f + sp.cos(phi_0)*phi*N_f0) + \
    (l_b - sp.cos(eps)*rho_f)*(beta_0*N_f + beta*N_f0) + \
    rho_f*(sp.sin(phi_0)*N_f + sp.cos(phi_0)*phi*N_f0) - \
    rho_r*(N_r0*sp.cos(phi_0)*phi + N_r*sp.sin(phi_0)) + \
    m*g*h*(sp.cos(phi_0)*phi) - m_b*z_b*g*beta + m_f*e_f*g*sp.cos(delta_0)*delta

mx_v = sp.Eq(mx_v_left, mx_v_right)


mz_v_left = (m*b**2 + Izz)*psi_ddot + (m*b*h - Ixz)*phi_ddot + \
    (m_f*e_f*b_f + Ifzz*sp.cos(eps))*delta_ddot + (Ibxx*sp.sin(eps) - m_b*z_b*b_b)*beta_ddot + \
    m*b*(Vy_dot + Vx0*psi_0_dot + Vx0*phi_dot) - \
    Iwr*(omega_r0*phi_dot + omega_r_dot*sp.sin(phi_0)) - \
    Iwf*(omega_f0*phi_f_dot + omega_f_dot*sp.sin(phi_f0))

mz_v_right = w*(-Y_f0*sp.sin(Delta_0)*Delta + Y_f*sp.cos(Delta_0)) - \
    rho_r*(Xr0*sp.cos(phi_0)*phi) + (h_a*D - b_a*L)*sp.cos(phi_0)*phi + M_rz + M_fz

mz_v = sp.Eq(mz_v_left, mz_v_right)


steer_v_left = (m_f*e_f**2 + Ifzz)*delta_ddot + (m_f*e_f*h_f + Ifzz*sp.sin(eps))*phi_ddot - \
    m_b*e_b*z_b*beta_ddot + (m_f*e_f*b_f + Ifzz*sp.cos(eps))*psi_ddot + \
    m_f*e_f*(Vy_dot + Vx0*psi_dot) + \
    Iwf*(sp.sin(eps)*(omega_f0*psi_dot + omega_f*psi_0_dot) - sp.cos(eps)*omega_f0*phi_dot) - \
    Iwf*(omega_f0 * beta_dot + omega_f*beta_0_dot + omega_f_dot*beta_0)

steer_v_right = M_delta - c_delta * delta_dot -  a_n*Y_f + M_fz*sp.cos(eps) + \
    (a_n - rho_f*sp.sin(eps))*(sp.sin(phi_f0)*N_f + sp.cos(phi_f0)*phi_f*N_f0) + \
    (l_b*sp.sin(eps) + a_n*sp.cos(eps))*(beta_0*N_f + beta*N_f0) + \
    g*sp.sin(eps)*(m_f*e_f*sp.cos(delta_0)*delta - m_b*z_b*beta) + g*m_f*e_f*sp.cos(phi_0)*phi

steer_v = sp.Eq(steer_v_left, steer_v_right)


fork_v_left = -(m_b*b_b*z_b + Ibxx*sp.sin(eps))*psi_ddot + (Ibxx*sp.cos(eps) - m_b*h_b*z_b)*phi_ddot - \
    m_b*e_b*z_b*delta_ddot + (m_b*z_b**2 + Ibzz)*beta_ddot - m_b*z_b*(Vy_dot + Vx0*psi_dot) + \
    Iwf*(omega_f0*phi_f0_dot + (omega_f0*psi_dot + omega_f*psi_0_dot)*sp.cos(eps))

fork_v_right = -l_b*(-Y_f0*sp.sin(phi_f0)*phi_f + Y_f*sp.cos(phi_f0)) - M_fz*sp.sin(eps) +\
    (l_b - rho_f*sp.cos(eps))*(N_f0*sp.cos(phi_f0)*phi_f + N_f*sp.sin(phi_f0)) - \
    m_b*z_b*(sp.cos(delta_0)*delta*sp.cos(eps) - g*sp.cos(phi_f0)*phi_f0)

fork_v = sp.Eq(fork_v_left, fork_v_right)

# %%
Y_f.simplify().collect(phi, delta, beta, Vy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 Y_f.simplify().collect(phi, delta, beta, Vy)
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/core/expr.py:3763, in Expr.collect(self, syms, func, evaluate, exact, distribute_order_term)
#    3761 """See the collect function in sympy.simplify"""
#    3762 from sympy.simplify.radsimp import collect
# -> 3763 return collect(self, syms, func, evaluate, exact, distribute_order_term)
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/simplify/radsimp.py:390, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     385     expr = expr.func(*[
#     386             collect(a, syms, func, True, exact, distribute_order_term)
#     387             for a in expr.args if a != o]) + o
#     388 elif expr.is_Mul:
#     389     return expr.func(*[
# --> 390         collect(term, syms, func, True, exact, distribute_order_term)
#     391         for term in expr.args])
#     392 elif expr.is_Pow:
#     393     b = collect(
#     394         expr.base, syms, func, True, exact, distribute_order_term)
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/simplify/radsimp.py:393, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     389         return expr.func(*[
#     390             collect(term, syms, func, True, exact, distribute_order_term)
#     391             for term in expr.args])
#     392     elif expr.is_Pow:
# --> 393         b = collect(
#     394             expr.base, syms, func, True, exact, distribute_order_term)
#     395         return Pow(b, expr.exp)
#     397 syms = [expand_power_base(i, deep=False) for i in syms]
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/simplify/radsimp.py:390, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     385     expr = expr.func(*[
#     386             collect(a, syms, func, True, exact, distribute_order_term)
#     387             for a in expr.args if a != o]) + o
#     388 elif expr.is_Mul:
#     389     return expr.func(*[
# --> 390         collect(term, syms, func, True, exact, distribute_order_term)
#     391         for term in expr.args])
#     392 elif expr.is_Pow:
#     393     b = collect(
#     394         expr.base, syms, func, True, exact, distribute_order_term)
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/simplify/radsimp.py:393, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     389         return expr.func(*[
#     390             collect(term, syms, func, True, exact, distribute_order_term)
#     391             for term in expr.args])
#     392     elif expr.is_Pow:
# --> 393         b = collect(
#     394             expr.base, syms, func, True, exact, distribute_order_term)
#     395         return Pow(b, expr.exp)
#     397 syms = [expand_power_base(i, deep=False) for i in syms]
#
# File ~/miniforge3/lib/python3.12/site-packages/sympy/simplify/radsimp.py:463, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     459         collected[key] = val + order_term
#     461 if func is not None:
#     462     collected = {
# --> 463         key: func(val) for key, val in collected.items()}
#     465 if evaluate:
#     466     return Add(*[key*val for key, val in collected.items()])
#
# TypeError: 'Mul' object is not callable

# %%
sum_y
# Out:
# Eq(-betabarddot*m_b*z_b + deltabarddot*e_f*m_f + m*(V_x0*psibardot + Vbardot_y0 + b*psibarddot + h*varphibarddot*cos(varphi_0)), -Deltabar*N_f0*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0)))*sin(Delta_0) + Deltabar*X_f0*cos(Delta_0) - L*varphibar*cos(varphi_0) + N_r*(alphaprime_r0*k_alpha_r + k_gamma_r*varphi_0) + N_r0*alphabarprime_r*k_alpha_r + N_r0*k_gamma_r*varphibar + Xbar_f*sin(Delta_0) + (N_f*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_alpha_f + N_f0*k_gamma_f*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))*cos(Delta_0))

# %%
mx_v
# Out:
# Eq(I_omega_f*(Delta_0*omegabardot_f + Deltabardot*V_x0/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0))) + I_omega_f*(V_x0*psibardot/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + V_x0*psidot_0/(-Deltabar*R_f*sin(Delta_0) - rho_f*(Deltabar*sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*sin(Delta_0) + Deltabar*sin(Delta_0) + (varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*cos(Delta_0)/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)))) + I_omega_r*(V_x0*psibardot/(R_r + rho_r*(cos(varphi_0) - 1)) + V_x0*psidot_0*rho_r*varphibar*sin(varphi_0)/(R_r + rho_r*(cos(varphi_0) - 1))**2) + betabarddot*(I_bxx*cos(epsilon) - h_b*m_b*z_b) + deltabarddot*(I_fzz*sin(epsilon) + e_f*h_f*m_f) + h*m*(V_x0*psibardot + Vbar_y) + psibarddot*(I_xx + h**2*m) + psibarddot*(-I_xz + b*h*m), -L*b_a*betabar_0*varphibar*(l_b - rho_f*cos(epsilon))*sin(varphi_0)/w_a - L*b_a*rho_f*varphibar*sin(varphi_0)**2/w_a - L*b_a*varphibar*(a_n - rho_f*sin(epsilon))*sin(varphi_0)*sin((Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))/cos(epsilon))/w_a - L*rho_r*varphibar*(b_a/w_a - 1)*sin(varphi_0)**2 - betabar*g*m_b*z_b + e_f*g*m_f*(-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos((Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))/cos(epsilon))/cos(epsilon) + g*h*m*varphibar*cos(varphi_0))

# %%
mz_v
# Out:
# Eq(-I_omega_f*(V_x0*varphibardot_f/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + omegabardot_f*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) - I_omega_r*(V_x0*varphibardot/(R_r + rho_r*(cos(varphi_0) - 1)) + omegabardot_r*sin(varphi_0)) + b*m*(V_x0*psidot_0 + V_x0*varphibardot + Vbardot_y0) + betabarddot*(I_bxx*sin(epsilon) - b_b*m_b*z_b) + deltabarddot*(I_fzz*cos(epsilon) + b_f*e_f*m_f) + psibarddot*(I_zz + b**2*m) + varphibarddot*(-I_xz + b*h*m), Mbar_rz + N_f*(alphaprime_f0*k_a_f + k_t_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_a_f + N_f0*k_t_f*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - X_r0*rho_r*varphibar*cos(varphi_0) + varphibar*(D*h_a - L*b_a)*cos(varphi_0) + w*(-Deltabar*N_f0*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0)))*sin(Delta_0) + (N_f*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_alpha_f + N_f0*k_gamma_f*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))*cos(Delta_0)))

# %%
steer_v
# Out:
# Eq(I_omega_f*(-V_x0*varphibardot*cos(epsilon)/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + (V_x0*psibardot/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + V_x0*psidot_0/(-Deltabar*R_f*sin(Delta_0) - rho_f*(Deltabar*sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*sin(Delta_0) + Deltabar*sin(Delta_0) + (varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*cos(Delta_0)/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))))*sin(epsilon)) - I_omega_f*(V_x0*betabardot/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + V_x0*betabardot_0/(-Deltabar*R_f*sin(Delta_0) - rho_f*(Deltabar*sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*sin(Delta_0) + Deltabar*sin(Delta_0) + (varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*cos(Delta_0)/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))) + betabar_0*omegabardot_f) - betabarddot*e_b*m_b*z_b + deltabarddot*(I_fzz + e_f**2*m_f) + e_f*m_f*(V_x0*psibardot + Vbardot_y0) + psibarddot*(I_fzz*cos(epsilon) + b_f*e_f*m_f) + varphibarddot*(I_fzz*sin(epsilon) + e_f*h_f*m_f), -L*b_a*betabar_0*varphibar*(a_n*cos(epsilon) + l_b*sin(epsilon))*sin(varphi_0)/w_a - L*b_a*varphibar*(a_n - rho_f*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*sin(varphi_0)/w_a + M_delta - a_n*(N_f*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_alpha_f + N_f0*k_gamma_f*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)) - c_delta*deltabardot + e_f*g*m_f*varphibar*cos(varphi_0) + g*(-betabar*m_b*z_b + e_f*m_f*(-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos((Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))/cos(epsilon))/cos(epsilon))*s ...

# %%
fork_v
# Out:
# Eq(I_omega_f*(V_x0*varphidot_f0/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + (V_x0*psibardot/((R_f + rho_f*(sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) - 1))*cos(Delta_0)) + V_x0*psidot_0/(-Deltabar*R_f*sin(Delta_0) - rho_f*(Deltabar*sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*sin(Delta_0) + Deltabar*sin(Delta_0) + (varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*cos(Delta_0)/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))))*cos(epsilon)) + betabarddot*(I_bzz + m_b*z_b**2) - deltabarddot*e_b*m_b*z_b - m_b*z_b*(V_x0*psibardot + Vbardot_y0) + psibarddot*(-I_bxx*sin(epsilon) - b_b*m_b*z_b) + varphibarddot*(I_bxx*cos(epsilon) - h_b*m_b*z_b), -L*b_a*varphibar*(l_b - rho_f*cos(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))*sin(varphi_0)/w_a - l_b*(-N_f0*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0)))*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))*(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2) + sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*(N_f*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_alpha_f + N_f0*k_gamma_f*(varphibar*cos(varphi_0) + (betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0))*cos(epsilon) + (-varphibar*(Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(varphi_0)/cos(epsilon) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos(varphi_0)/cos(epsilon))*sin(epsilon))/sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2))) - m_b*z_b*(-g*sqrt(1 - (betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0))**2)*asin(betabar_0*cos(epsilon)*cos(varphi_0) + (Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))*sin(epsilon)*cos(varphi_0)/cos(epsilon) + sin(varphi_0)) + (-Delta_0*varphibar*sin(varphi_0) + Deltabar*cos(varphi_0) + betabar*sin(epsilon))*cos((Delta_0*cos(varphi_0) + betabar_0*sin(epsilon))/cos(epsilon))) - (N_f*(alphaprime_f0*k_a_f + k_t_f*asin(betabar_0*cos(eps ...

# %%
sum_y.simplify()
# Out:
# Eq(-betabarddot*m_b*z_b + deltabarddot*e_f*m_f + m*(V_x0*psibardot + Vbardot_y0 + b*psibarddot + h*varphibarddot*cos(varphi_0)), (sqrt((-(Delta_0*sin(epsilon)*cos(varphi_0)**2 + betabar_0*cos(varphi_0) + sin(varphi_0)*cos(epsilon))**2 + cos(epsilon)**2)/cos(epsilon)**2)*(-Deltabar*N_f0*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(Delta_0*cos(varphi_0)**2*tan(epsilon) + betabar_0*cos(varphi_0)/cos(epsilon) + sin(varphi_0)))*sin(Delta_0) + Deltabar*X_f0*cos(Delta_0) - L*varphibar*cos(varphi_0) + N_r*(alphaprime_r0*k_alpha_r + k_gamma_r*varphi_0) + N_r0*alphabarprime_r*k_alpha_r + N_r0*k_gamma_r*varphibar + Xbar_f*sin(Delta_0))*cos(epsilon) + (N_f0*k_gamma_f*(-2*Delta_0*varphibar*sin(epsilon)*sin(varphi_0)*cos(varphi_0) + Deltabar*sin(epsilon)*cos(varphi_0)**2 + betabar*cos(varphi_0) - betabar_0*varphibar*sin(varphi_0) + varphibar*cos(epsilon)*cos(varphi_0)) + sqrt((-(Delta_0*sin(epsilon)*cos(varphi_0)**2 + betabar_0*cos(varphi_0) + sin(varphi_0)*cos(epsilon))**2 + cos(epsilon)**2)/cos(epsilon)**2)*(N_f*(alphaprime_f0*k_alpha_f + k_gamma_f*asin(Delta_0*cos(varphi_0)**2*tan(epsilon) + betabar_0*cos(varphi_0)/cos(epsilon) + sin(varphi_0))) + N_f0*alphabarprime_f*k_alpha_f)*cos(epsilon))*cos(Delta_0))/(sqrt((-(Delta_0*sin(epsilon)*cos(varphi_0)**2 + betabar_0*cos(varphi_0) + sin(varphi_0)*cos(epsilon))**2 + cos(epsilon)**2)/cos(epsilon)**2)*cos(epsilon)))
